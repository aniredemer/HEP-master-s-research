# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cmath

G_F = 1.1663787*10**(-5)
V_cb = 40.9*10**(-3)
tau_l_b = 1.409*10**(-12)

tau_total = 6.58*10**(-25)/tau_l_b
#print(tau_total)

#masses(GeV)
m_l_b = 5.6202
m_l_c = 2.59225
m_tau = 1.77686
m_e = 0.000511
m_uon = 0.1057
m_b = 4.18
m_c = 1.275
#w =1.1
#spacing
#w = np.linspace(1,((m_l_b**2+m_l_c**2-m_tau**2)/(2*m_l_b*m_l_c)),1000)
#w =1.1
w = np.linspace(1,1.2063032748874114,1000)
def D_gamma(w):

  #w = np.linspace(1,((m_l_b**2+m_l_c**2-m_tau**2)/(2*m_l_b*m_l_c)),1000)
  m_l = m_tau


  #wilson coefficents
  # C_V_LL = 0
  # C_V_RL = 0
  # C_S_LL = 0
  # C_S_RL = 0

  # C_A = (1+C_V_LL - C_V_RL)  #C_A = C_A_L (""''"""""""""""""""""""""""""""""""")
  # C_V = (1+C_V_LL + C_V_RL)  #C_V = C_V_L  (only left handed leptons considered)
  # C_P = C_S_LL - C_S_RL
  # C_S = C_S_LL + C_S_RL
  # C_T =0

  #L fit 6
  # C_S = -0.16
  # C_V = 1.26
  # C_A = 1.10
  # C_T = 0.01
  # C_P = -0.26

  # SM fit
  C_V = 1
  C_A = 1
  C_S = 0
  C_P = 0
  C_T = 0

  # #L fit 7
  # C_V = 1.70
  # C_A = 1.02
  # C_S = -1.32
  # C_P = -0.22
  # C_T = -0.01

  l = (m_l_b/m_l_c)
  m_1 = m_l_b + m_l_c
  m_2 = m_l_b - m_l_c


  #M's,q's,s
  m_w = m_l_b-w*m_l_c
  q_2 =(m_l_b**2+m_l_c**2 - 2*m_l_b*m_l_c*w)
  #s_2 = (m_l_b-m_l_c)**2-q_2
  #s_1 = (m_l_b+m_l_c)**2-q_2
  s_1 = 2*m_l_b*m_l_c*(w+1)
  s_2 = 2*m_l_b*m_l_c*(w-1)


  #defining f'sg'sh's
  #form factors
  f_0 = 0.545 + (-2.21)*(w-1)
  f_plus = 0.1628 + 1.16*(w-1)
  f_90 = 0.1690 + 0.57*(w-1)

  g_0 = 0.221 +  0.94*(w-1)
  g_plus = 0.582 + (-2.24)*(w-1)
  g_90 = 1.22 + (-6.1)*(w-1)

  h_plus = 0.1908 +0.47*(w-1)
  h_90 = 0.1860 + 0.98*(w-1)
  h_tilda_plus = 1.15 - 5.8*(w-1)
  h_tilda_90 = 0.543 -2.12*(w-1)





  #defining F,T,G's
  G_1 = -f_90
  G_2 = m_l_b*(f_0*(m_1/q_2) + f_plus *(m_2/s_2)*(1-(m_1*m_2/q_2)) + f_90*2*(m_l_c/s_2))
  G_3 = m_l_c*(-f_0*(m_1/q_2) + f_plus*(m_2/s_2)*(1+(m_1*m_2/q_2))-f_90*2*(m_l_b/s_2))
  F_1 = -g_90
  F_2 = m_l_b*(-g_0*(m_2/q_2) - g_plus*(m_1/s_1)*(1-((m_1*m_2)/q_2)) + g_90*2*(m_l_c/s_1))
  F_3 = m_l_c*(g_0*(m_2/q_2) - g_plus*(m_1/s_1)*(1+((m_1*m_2)/q_2)) + g_90*2*(m_l_b/s_1))
  T_1 = 2*(m_l_b**2)*((h_plus/s_2) -((m_2)**2/(q_2*s_2))*h_90 - (1/s_1)*h_tilda_plus + ((m_1**2/(q_2*s_1)))*h_tilda_90)
  T2_0 = (m_l_c/s_2)*h_plus
  T2_1 = (1/2)*((m_l_b - m_l_c)/q_2)*((m_l_b**2 - m_l_c**2-q_2)/s_2)*h_90
  T2_2 = (1/2)*((m_l_b +m_l_c)/q_2)*h_tilda_90
  T_2 = 2*m_l_b*(T2_0 - T2_1 + T2_2)
  T_3 = 2*m_l_b*(-(m_l_b/s_2)*h_plus + (m_2/(2*q_2*s_2))*(m_l_b**2-m_l_c**2+q_2)*h_90 - (m_1/(2*q_2))*h_tilda_90)
  T_4 = h_plus


  F_S = -(1/(m_b+m_c))*(m_2*F_1 + m_w*F_2 + (m_l_b*w-m_l_c)*F_3)
  F_P = (1/(m_b-m_c))*(-(m_l_b + m_l_c)*G_1 + (m_l_b-m_l_c*w)*G_2 + (m_l_b*w -m_l_c)*G_3)
  #defining w's
  w_1 =(1/2)*((w-1)*(abs(C_A))**2*F_1**2 + (w+1)*(abs(C_V))**2*G_1**2)

  w_2_0 = ((abs(C_A))**(2)/2)*(2*F_1*F_2 +(w+1)*F_2**(2) + ((2*m_l_b)/m_l_c)*((F_1+F_2)*(F_1+F_3)+w*F_2*F_3) + (m_l_b**(2)/m_l_c**(2))*(2*F_1*F_3+(w+1)*F_3**(2)))
  w_2_1 = ((abs(C_V))**(2)/2)*(2*G_1*G_2 + (w-1)*G_2**2 + ((2*m_l_b)/m_l_c)*(w*G_2*G_3 + (G_1-G_2)*(G_1 + G_3)) + (m_l_b/m_l_c)**(2)*((w-1)*G_3**2-2*G_1*G_3))
  w_2 = w_2_0 + w_2_1

  w_3 = 2*(m_l_b/m_l_c)*((C_A*np.conjugate(C_V)).real)*F_1*G_1

  w_4 = (1/2)*(m_l_b/m_l_c)**(2)*((abs(C_A))**(2)*(2*F_1*F_3 +(w+1)*F_3**2)-(abs(C_V))**(2)*(2*G_1*G_3 +(1-w)*G_3**(2)))

  w_5_0 = (F_1+F_2)*(F_1+F_3) + w*F_2*F_3 + (m_l_b/m_l_c)*(2*F_1*F_3 + (w+1)*F_3**2)
  w_5_1 = (G_1-G_2)*(G_1+G_3)+w*G_2*G_3 - (m_l_b/m_l_c)*(2*G_1*G_3 + (1-w)*G_3**2)
  w_5 = (-1)*(m_l_b/m_l_c)*((abs(C_A))**2*w_5_0 + (abs(C_V))**2*w_5_1)

  w_SP =(1/2)*((w+1)*(abs(C_P))**2*F_S**2 + (w-1)*(abs(C_S))**2*F_P**2)

  #W's for other SF's

  w_I1_0 = C_A*(np.conjugate(C_P))*(F_S*F_1*(1+(m_l_b/m_l_c)) + (1+w)*F_S*(F_2 +(m_l_b/m_l_c)*F_3))
  w_I1_1 = C_V*(np.conjugate(C_S))*(F_P*G_1*(1-(m_l_b/m_l_c)) - (1-w)*F_P*(G_2 +(m_l_b/m_l_c)*G_3))
  w_I1 = w_I1_0 + w_I1_1

  w_I2 = (m_l_b/m_l_c)*(C_V*np.conjugate(C_S)*F_P*(G_1 +(1-w)*G_3)- C_A*np.conjugate(C_P)*F_S*(F_1+(1+w)*F_3))


  w_I3 = np.conjugate(C_T)*C_P*F_S*(T_1*(1+w)+T_3 - (m_l_b/m_l_c)*(T_2+T_4)) - np.conjugate(C_T)*C_S*(m_l_b/m_l_c)*F_P*T_4

  w_I4_0 = F_1*T_1*(1+(m_l_b/m_l_c)) + (m_l_b/m_l_c)*F_1*(T_3-T_2)
  w_I4_1 = (F_2 + F_3*(m_l_b/m_l_c))*((m_l_b/m_l_c)*(T_2+T_4) - T_1*(1+w)-T_3)
  w_I4_2 = (m_l_b/m_l_c)*(G_1*(T_2+T_3) + T_4*(G_2 + (m_l_b/m_l_c)*G_3))
  w_I4 = np.conjugate(C_T)*C_A*(w_I4_0 - w_I4_1) - np.conjugate(C_T)*C_V*w_I4_2

  w_I5_0 = (F_1*(T_1 +T_3) +F_3*(T_1*(1+w)+ T_3 - (m_l_b/m_l_c)*(T_2+T_4)))
  w_I5_1 = (G_1*T_3 + (m_l_b/m_l_c)*G_3*T_4)
  w_I5 = -np.conjugate(C_T)*C_A*l*w_I5_0 + np.conjugate(C_T)*C_V*l*w_I5_1

  w_I6_0 = ((1-w)*(T_2 + T_3) + (1-(m_l_b/m_l_c))*T_4)
  w_I6_1 = ((m_l_b/m_l_c)*(T_2 + T_4) + T_4 +w*(T_3-T_2) - (m_l_b/m_l_c)*T_3)
  w_I6 = -np.conjugate(C_T)*C_A*F_1*w_I6_0 -np.conjugate(C_T)*C_V*G_1*w_I6_1

  w_I7_0 =  (T_3*(1-w)-l*T_4)
  w_I7_1 = (l*(T_2+T_4)+w*T_3)
  w_I7 = np.conjugate(C_T)*C_A*F_1*w_I7_0 + np.conjugate(C_T)*C_V*G_1*w_I7_1

  w_T_2_0 = (1/l)**2*((1+w)*T_1**2 + 2*T_1*T_3)
  w_T_2_1 = 2*(1/l)*(w*(w+1)*T_1**2 + T_1*(T_2 +2*w*T_3 + T_4) + T_2*T_3)
  w_T_2_2 = (1+w)*T_1**2 - 2*w*(T_2**2 + T_3**2) + 2*T_1*(2*w*(T_2+T_4) + T_3) +2*(T_2+T_3)*(T_2 + T_3 + 2*T_4)
  w_T_2_3 = 2*l*(T_1*(T_2 + T_4) + T_2*(T_3+2*T_4) + 2*T_4*(T_3 +T_4))
  w_T_2 = ((abs(C_T))**2/2)*(w_T_2_0 - w_T_2_1 + w_T_2_2 - w_T_2_3)

  w_T_3 = ((abs(C_T))**(2)/2)*((1+w)*T_1**2 + 2*T_1*T_3 + 2*(1-w)*T_3**2 -2*l*(T_1*(T_2+T_4)+ T_3*(T_2 +2*T_4)))

  w_T_4_0 = (1/l)*(w*(1+w)*T_1**(2) + 2*w*T_1*T_3)
  w_T_4_1 = -T_1**(2)*(1+w)-2*w*(T_2+T_4)*T_1 -2*T_3*(T_1 + T_2 + (1-w)*T_3 +T_4)
  w_T_4_2 = 2*l*(T_4*(T_1+T_2+2*T_3) + T_2*(T_1 + T_3) + T_4**2)
  w_T_4 = ((abs(C_T))**(2)/2)*(w_T_4_0 + w_T_4_1 + w_T_4_2)

  #defining A,B,C
  A_0 = 2*w_1 -w_2 +(m_w/m_l_b)*w_3 +w_SP + 4*(m_w/m_l_b)*((w_I3).real)
  A_1 = 8*(w_T_2 -(q_2/m_l_b**2)*w_T_3-(2*m_w/m_l_b)*w_T_4)
  A_2 = (m_l/m_l_b)*((w_I2 +4*w_I4 +4*(m_w/m_l_b)*w_I5 + 12*w_I7).real)
  A_3 = (m_l/m_l_b)**2*(w_4 -16*w_T_3)

  A = ((q_2-m_l**2)/m_l_b**2)*(A_0 +A_1 +A_2 +A_3)

  B = -2*(q_2/m_l_b**2)*(w_3 +4*(w_I3).real) + 4*(m_w/m_l_b)*(w_2 -16*w_T_2) + 2*(m_l/m_l_b)*((w_I1 -4*(m_w/m_l_b)*w_I4 -4*(q_2/m_l_b**2)*w_I5 +12*w_I6).real) + 2*(m_l/m_l_b)**2*(w_5 -32*w_T_4)

  C = -4*(w_2 -16*w_T_2)


  #defining a0,a1,a2
  a_0 = (q_2/(q_2-m_l**(2)))*A + (1/2)*(m_w/m_l_b)*B + ((q_2-m_l**(2))*m_w**(2)*C)/(4*q_2*m_l_b**(2))
  a_2 = (w**2 -1)*(m_l_c/m_l_b)**(2)*((q_2 - m_l**2)/(4*q_2))*C

  n_0_value = 3 * a_0 + a_2
  gamma_0 = G_F**2*(abs(V_cb))**2*m_l_c**3*m_l_b**2*np.sqrt(w**2-1)*(1-(m_l**2/q_2))**2*n_0_value*(1/24*np.pi**3)
  return gamma_0

print(D_gamma(w))
# Out:
# [           nan 1.01876308e-13 1.45139323e-13 1.79056513e-13
#  2.08248588e-13 2.34489541e-13 2.58681265e-13 2.81354808e-13
#  3.02853071e-13 3.23412050e-13 3.43201961e-13 3.62350064e-13
#  3.80954255e-13 3.99091599e-13 4.16823935e-13 4.34201685e-13
#  4.51266532e-13 4.68053340e-13 4.84591576e-13 5.00906365e-13
#  5.17019304e-13 5.32949091e-13 5.48712013e-13 5.64322340e-13
#  5.79792639e-13 5.95134030e-13 6.10356391e-13 6.25468534e-13
#  6.40478346e-13 6.55392908e-13 6.70218599e-13 6.84961179e-13
#  6.99625863e-13 7.14217382e-13 7.28740039e-13 7.43197756e-13
#  7.57594109e-13 7.71932371e-13 7.86215538e-13 8.00446356e-13
#  8.14627348e-13 8.28760831e-13 8.42848938e-13 8.56893635e-13
#  8.70896734e-13 8.84859903e-13 8.98784688e-13 9.12672512e-13
#  9.26524694e-13 9.40342451e-13 9.54126910e-13 9.67879112e-13
#  9.81600024e-13 9.95290537e-13 1.00895148e-12 1.02258361e-12
#  1.03618764e-12 1.04976423e-12 1.06331397e-12 1.07683744e-12
#  1.09033513e-12 1.10380754e-12 1.11725509e-12 1.13067820e-12
#  1.14407724e-12 1.15745255e-12 1.17080443e-12 1.18413319e-12
#  1.19743908e-12 1.21072234e-12 1.22398319e-12 1.23722182e-12
#  1.25043841e-12 1.26363313e-12 1.27680612e-12 1.28995749e-12
#  1.30308737e-12 1.31619585e-12 1.32928302e-12 1.34234895e-12
#  1.35539370e-12 1.36841732e-12 1.38141984e-12 1.39440131e-12
#  1.40736173e-12 1.42030112e-12 1.43321949e-12 1.44611683e-12
#  1.45899312e-12 1.47184836e-12 1.48468251e-12 1.49749554e-12
#  1.51028742e-12 1.52305811e-12 1.53580756e-12 1.54853572e-12
#  1.56124253e-12 1.57392794e-12 1.58659187e-12 1.59923426e-12
#  1.61185505e-12 1.62445414e-12 1.63703148e-12 1.64958697e-12
#  1.66212054e-12 1.67463209e-12 1.68712154e-12 1.69958881e-12
#  1.71203379e-12 1.72445639e-12 1.73685652e-12 1.74923408e-12
#  1.76158897e-12 1.77392109e-12 1.78623034e-12 1.79851661e-12
#  1.81077980e-12 1.82301980e-12 1.83523651e-12 1.84742983e-12
#  1.85959963e-12 1.87174582e-12 1.88386829e-12 1.89596692e-12
#  1.90804160e-12 1.92009223e-12 1.93211869e-12 1.94412087e-12
#  1.95609866e-12 1.96805195e-12 1.97998062e-12 1.99188456e-12
#  2.00376367e-12 2.01561782e-12 2.02744691e-12 2.03925082e-12
#  2.05102944e-12 2.06278266e-12 2.07451037e-12 2.08621245e-12
#  2.09788879e-12 2.10953929e-12 2.12116383e-12 2.13276229e-12
#  2.14433458e-12 2.15588058e-12 2.16740017e-12 2.17889325e-12
#  2.19035972e-12 2.20179945e-12 2.21321235e-12 2.22459831e-12
#  2.23595721e-12 2.24728896e-12 2.25859344e-12 2.26987055e-12
#  2.28112019e-12 2.29234224e-12 2.30353661e-12 2.31470320e-12
#  2.32584189e-12 2.33695259e-12 2.34803519e-12 2.35908959e-12
#  2.37011570e-12 2.38111341e-12 2.39208262e-12 2.40302324e-12
#  2.41393516e-12 2.42481830e-12 2.43567254e-12 2.44649780e-12
#  2.45729397e-12 2.46806098e-12 2.47879871e-12 2.48950708e-12
#  2.50018599e-12 2.51083535e-12 2.52145508e-12 2.53204507e-12
#  2.54260524e-12 2.55313551e-12 2.56363577e-12 2.57410594e-12
#  2.58454594e-12 2.59495568e-12 2.60533507e-12 2.61568402e-12
#  2.62600246e-12 2.63629029e-12 2.64654744e-12 2.65677382e-12
#  2.66696935e-12 2.67713395e-12 2.68726753e-12 2.69737003e-12
#  2.70744135e-12 2.71748142e-12 2.72749017e-12 2.73746751e-12
#  2.74741337e-12 2.75732767e-12 2.76721034e-12 2.77706130e-12
#  2.78688048e-12 2.79666781e-12 2.80642322e-12 2.81614662e-12
#  2.82583796e-12 2.83549716e-12 2.84512415e-12 2.85471886e-12
#  2.86428123e-12 2.87381118e-12 2.88330865e-12 2.89277358e-12
#  2.90220589e-12 2.91160552e-12 2.92097241e-12 2.93030650e-12
#  2.93960771e-12 2.94887599e-12 2.95811128e-12 2.96731352e-12
#  2.97648263e-12 2.98561857e-12 2.99472128e-12 3.00379069e-12
#  3.01282675e-12 3.02182940e-12 3.03079859e-12 3.03973425e-12
#  3.04863633e-12 3.05750478e-12 3.06633954e-12 3.07514055e-12
#  3.08390777e-12 3.09264115e-12 3.10134062e-12 3.11000614e-12
#  3.11863766e-12 3.12723512e-12 3.13579848e-12 3.14432769e-12
#  3.15282269e-12 3.16128345e-12 3.16970991e-12 3.17810203e-12
#  3.18645975e-12 3.19478304e-12 3.20307185e-12 3.21132613e-12
#  3.21954584e-12 3.22773093e-12 3.23588137e-12 3.24399710e-12
#  3.25207809e-12 3.26012430e-12 3.26813568e-12 3.27611220e-12
#  3.28405381e-12 3.29196047e-12 3.29983214e-12 3.30766880e-12
#  3.31547039e-12 3.32323688e-12 3.33096823e-12 3.33866441e-12
#  3.34632538e-12 3.35395111e-12 3.36154155e-12 3.36909668e-12
#  3.37661646e-12 3.38410085e-12 3.39154983e-12 3.39896336e-12
#  3.40634141e-12 3.41368394e-12 3.42099092e-12 3.42826233e-12
#  3.43549813e-12 3.44269830e-12 3.44986279e-12 3.45699159e-12
#  3.46408466e-12 3.47114198e-12 3.47816351e-12 3.48514924e-12
#  3.49209912e-12 3.49901314e-12 3.50589127e-12 3.51273349e-12
#  3.51953976e-12 3.52631006e-12 3.53304437e-12 3.53974266e-12
#  3.54640491e-12 3.55303110e-12 3.55962120e-12 3.56617518e-12
#  3.57269303e-12 3.57917473e-12 3.58562024e-12 3.59202956e-12
#  3.59840265e-12 3.60473951e-12 3.61104010e-12 3.61730441e-12
#  3.62353242e-12 3.62972410e-12 3.63587945e-12 3.64199843e-12
#  3.64808104e-12 3.65412726e-12 3.66013706e-12 3.66611042e-12
#  3.67204735e-12 3.67794780e-12 3.68381178e-12 3.68963926e-12
#  3.69543022e-12 3.70118466e-12 3.70690255e-12 3.71258389e-12
#  3.71822865e-12 3.72383682e-12 3.72940839e-12 3.73494335e-12
#  3.74044168e-12 3.74590336e-12 3.75132839e-12 3.75671675e-12
#  3.76206843e-12 3.76738342e-12 3.77266170e-12 3.77790327e-12
#  3.78310811e-12 3.78827622e-12 3.79340757e-12 3.79850217e-12
#  3.80355999e-12 3.80858103e-12 3.81356529e-12 3.81851274e-12
#  3.82342339e-12 3.82829721e-12 3.83313421e-12 3.83793438e-12
#  3.84269770e-12 3.84742417e-12 3.85211377e-12 3.85676651e-12
#  3.86138237e-12 3.86596135e-12 3.87050344e-12 3.87500863e-12
#  3.87947692e-12 3.88390830e-12 3.88830276e-12 3.89266029e-12
#  3.89698090e-12 3.90126457e-12 3.90551130e-12 3.90972108e-12
#  3.91389391e-12 3.91802979e-12 3.92212870e-12 3.92619065e-12
#  3.93021562e-12 3.93420362e-12 3.93815464e-12 3.94206868e-12
#  3.94594573e-12 3.94978578e-12 3.95358884e-12 3.95735491e-12
#  3.96108397e-12 3.96477602e-12 3.96843107e-12 3.97204910e-12
#  3.97563012e-12 3.97917413e-12 3.98268111e-12 3.98615108e-12
#  3.98958402e-12 3.99297993e-12 3.99633881e-12 3.99966067e-12
#  4.00294549e-12 4.00619328e-12 4.00940403e-12 4.01257775e-12
#  4.01571443e-12 4.01881407e-12 4.02187667e-12 4.02490223e-12
#  4.02789074e-12 4.03084222e-12 4.03375665e-12 4.03663403e-12
#  4.03947437e-12 4.04227766e-12 4.04504391e-12 4.04777311e-12
#  4.05046527e-12 4.05312037e-12 4.05573843e-12 4.05831944e-12
#  4.06086341e-12 4.06337033e-12 4.06584020e-12 4.06827302e-12
#  4.07066880e-12 4.07302753e-12 4.07534922e-12 4.07763386e-12
#  4.07988146e-12 4.08209201e-12 4.08426552e-12 4.08640198e-12
#  4.08850140e-12 4.09056378e-12 4.09258912e-12 4.09457742e-12
#  4.09652868e-12 4.09844290e-12 4.10032009e-12 4.10216023e-12
#  4.10396334e-12 4.10572942e-12 4.10745846e-12 4.10915047e-12
#  4.11080544e-12 4.11242339e-12 4.11400430e-12 4.11554819e-12
#  4.11705504e-12 4.11852487e-12 4.11995768e-12 4.12135346e-12
#  4.12271221e-12 4.12403394e-12 4.12531865e-12 4.12656634e-12
#  4.12777701e-12 4.12895066e-12 4.13008729e-12 4.13118691e-12
#  4.13224951e-12 4.13327509e-12 4.13426366e-12 4.13521522e-12
#  4.13612976e-12 4.13700730e-12 4.13784782e-12 4.13865133e-12
#  4.13941784e-12 4.14014734e-12 4.14083982e-12 4.14149531e-12
#  4.14211378e-12 4.14269525e-12 4.14323972e-12 4.14374718e-12
#  4.14421763e-12 4.14465109e-12 4.14504753e-12 4.14540698e-12
#  4.14572943e-12 4.14601487e-12 4.14626331e-12 4.14647474e-12
#  4.14664918e-12 4.14678661e-12 4.14688704e-12 4.14695047e-12
#  4.14697690e-12 4.14696632e-12 4.14691874e-12 4.14683416e-12
#  4.14671257e-12 4.14655398e-12 4.14635839e-12 4.14612579e-12
#  4.14585618e-12 4.14554957e-12 4.14520594e-12 4.14482531e-12
#  4.14440767e-12 4.14395302e-12 4.14346136e-12 4.14293268e-12
#  4.14236699e-12 4.14176428e-12 4.14112455e-12 4.14044780e-12
#  4.13973403e-12 4.13898324e-12 4.13819543e-12 4.13737058e-12
#  4.13650871e-12 4.13560981e-12 4.13467387e-12 4.13370090e-12
#  4.13269088e-12 4.13164383e-12 4.13055974e-12 4.12943859e-12
#  4.12828040e-12 4.12708515e-12 4.12585285e-12 4.12458349e-12
#  4.12327707e-12 4.12193358e-12 4.12055303e-12 4.11913540e-12
#  4.11768069e-12 4.11618891e-12 4.11466004e-12 4.11309408e-12
#  4.11149103e-12 4.10985088e-12 4.10817363e-12 4.10645928e-12
#  4.10470782e-12 4.10291924e-12 4.10109354e-12 4.09923071e-12
#  4.09733076e-12 4.09539367e-12 4.09341943e-12 4.09140806e-12
#  4.08935953e-12 4.08727384e-12 4.08515099e-12 4.08299097e-12
#  4.08079378e-12 4.07855940e-12 4.07628784e-12 4.07397908e-12
#  4.07163312e-12 4.06924995e-12 4.06682957e-12 4.06437197e-12
#  4.06187714e-12 4.05934507e-12 4.05677576e-12 4.05416920e-12
#  4.05152539e-12 4.04884431e-12 4.04612595e-12 4.04337031e-12
#  4.04057739e-12 4.03774716e-12 4.03487964e-12 4.03197479e-12
#  4.02903263e-12 4.02605313e-12 4.02303630e-12 4.01998211e-12
#  4.01689057e-12 4.01376166e-12 4.01059537e-12 4.00739170e-12
#  4.00415064e-12 4.00087217e-12 3.99755628e-12 3.99420297e-12
#  3.99081223e-12 3.98738404e-12 3.98391840e-12 3.98041530e-12
#  3.97687472e-12 3.97329665e-12 3.96968109e-12 3.96602802e-12
#  3.96233744e-12 3.95860932e-12 3.95484367e-12 3.95104047e-12
#  3.94719970e-12 3.94332136e-12 3.93940544e-12 3.93545191e-12
#  3.93146079e-12 3.92743204e-12 3.92336566e-12 3.91926164e-12
#  3.91511996e-12 3.91094061e-12 3.90672358e-12 3.90246887e-12
#  3.89817644e-12 3.89384630e-12 3.88947843e-12 3.88507282e-12
#  3.88062946e-12 3.87614832e-12 3.87162941e-12 3.86707270e-12
#  3.86247819e-12 3.85784585e-12 3.85317569e-12 3.84846767e-12
#  3.84372180e-12 3.83893806e-12 3.83411643e-12 3.82925690e-12
#  3.82435946e-12 3.81942410e-12 3.81445079e-12 3.80943953e-12
#  3.80439030e-12 3.79930310e-12 3.79417790e-12 3.78901469e-12
#  3.78381346e-12 3.77857419e-12 3.77329688e-12 3.76798150e-12
#  3.76262805e-12 3.75723650e-12 3.75180685e-12 3.74633909e-12
#  3.74083319e-12 3.73528914e-12 3.72970694e-12 3.72408656e-12
#  3.71842800e-12 3.71273123e-12 3.70699625e-12 3.70122304e-12
#  3.69541160e-12 3.68956189e-12 3.68367392e-12 3.67774766e-12
#  3.67178311e-12 3.66578025e-12 3.65973907e-12 3.65365955e-12
#  3.64754169e-12 3.64138546e-12 3.63519086e-12 3.62895787e-12
#  3.62268648e-12 3.61637667e-12 3.61002845e-12 3.60364178e-12
#  3.59721666e-12 3.59075309e-12 3.58425103e-12 3.57771050e-12
#  3.57113146e-12 3.56451391e-12 3.55785785e-12 3.55116325e-12
#  3.54443011e-12 3.53765841e-12 3.53084815e-12 3.52399932e-12
#  3.51711190e-12 3.51018588e-12 3.50322126e-12 3.49621802e-12
#  3.48917616e-12 3.48209567e-12 3.47497653e-12 3.46781874e-12
#  3.46062230e-12 3.45338718e-12 3.44611340e-12 3.43880093e-12
#  3.43144977e-12 3.42405991e-12 3.41663135e-12 3.40916409e-12
#  3.40165810e-12 3.39411340e-12 3.38652997e-12 3.37890782e-12
#  3.37124693e-12 3.36354730e-12 3.35580893e-12 3.34803181e-12
#  3.34021595e-12 3.33236133e-12 3.32446797e-12 3.31653586e-12
#  3.30856499e-12 3.30055536e-12 3.29250699e-12 3.28441986e-12
#  3.27629398e-12 3.26812935e-12 3.25992597e-12 3.25168385e-12
#  3.24340299e-12 3.23508339e-12 3.22672506e-12 3.21832800e-12
#  3.20989223e-12 3.20141774e-12 3.19290454e-12 3.18435264e-12
#  3.17576205e-12 3.16713278e-12 3.15846485e-12 3.14975825e-12
#  3.14101300e-12 3.13222912e-12 3.12340661e-12 3.11454550e-12
#  3.10564579e-12 3.09670751e-12 3.08773066e-12 3.07871527e-12
#  3.06966136e-12 3.06056893e-12 3.05143802e-12 3.04226865e-12
#  3.03306083e-12 3.02381460e-12 3.01452997e-12 3.00520696e-12
#  2.99584562e-12 2.98644595e-12 2.97700800e-12 2.96753179e-12
#  2.95801735e-12 2.94846472e-12 2.93887392e-12 2.92924499e-12
#  2.91957797e-12 2.90987289e-12 2.90012979e-12 2.89034871e-12
#  2.88052970e-12 2.87067278e-12 2.86077802e-12 2.85084544e-12
#  2.84087511e-12 2.83086705e-12 2.82082134e-12 2.81073800e-12
#  2.80061711e-12 2.79045871e-12 2.78026285e-12 2.77002960e-12
#  2.75975901e-12 2.74945114e-12 2.73910606e-12 2.72872383e-12
#  2.71830451e-12 2.70784817e-12 2.69735489e-12 2.68682472e-12
#  2.67625776e-12 2.66565406e-12 2.65501371e-12 2.64433679e-12
#  2.63362337e-12 2.62287355e-12 2.61208740e-12 2.60126502e-12
#  2.59040649e-12 2.57951190e-12 2.56858135e-12 2.55761494e-12
#  2.54661277e-12 2.53557492e-12 2.52450152e-12 2.51339266e-12
#  2.50224846e-12 2.49106902e-12 2.47985446e-12 2.46860489e-12
#  2.45732044e-12 2.44600123e-12 2.43464737e-12 2.42325900e-12
#  2.41183625e-12 2.40037925e-12 2.38888813e-12 2.37736305e-12
#  2.36580413e-12 2.35421152e-12 2.34258538e-12 2.33092585e-12
#  2.31923308e-12 2.30750725e-12 2.29574850e-12 2.28395701e-12
#  2.27213294e-12 2.26027646e-12 2.24838775e-12 2.23646699e-12
#  2.22451436e-12 2.21253005e-12 2.20051425e-12 2.18846716e-12
#  2.17638897e-12 2.16427988e-12 2.15214010e-12 2.13996985e-12
#  2.12776933e-12 2.11553877e-12 2.10327840e-12 2.09098843e-12
#  2.07866910e-12 2.06632065e-12 2.05394332e-12 2.04153736e-12
#  2.02910301e-12 2.01664054e-12 2.00415021e-12 1.99163227e-12
#  1.97908701e-12 1.96651470e-12 1.95391562e-12 1.94129006e-12
#  1.92863831e-12 1.91596066e-12 1.90325743e-12 1.89052892e-12
#  1.87777545e-12 1.86499733e-12 1.85219490e-12 1.83936848e-12
#  1.82651842e-12 1.81364507e-12 1.80074876e-12 1.78782987e-12
#  1.77488875e-12 1.76192578e-12 1.74894133e-12 1.73593580e-12
#  1.72290956e-12 1.70986303e-12 1.69679660e-12 1.68371070e-12
#  1.67060573e-12 1.65748213e-12 1.64434034e-12 1.63118080e-12
#  1.61800395e-12 1.60481027e-12 1.59160021e-12 1.57837426e-12
#  1.56513289e-12 1.55187660e-12 1.53860589e-12 1.52532127e-12
#  1.51202327e-12 1.49871240e-12 1.48538920e-12 1.47205423e-12
#  1.45870803e-12 1.44535117e-12 1.43198423e-12 1.41860779e-12
#  1.40522245e-12 1.39182882e-12 1.37842750e-12 1.36501912e-12
#  1.35160433e-12 1.33818376e-12 1.32475808e-12 1.31132796e-12
#  1.29789408e-12 1.28445712e-12 1.27101780e-12 1.25757684e-12
#  1.24413495e-12 1.23069288e-12 1.21725138e-12 1.20381122e-12
#  1.19037317e-12 1.17693803e-12 1.16350661e-12 1.15007971e-12
#  1.13665817e-12 1.12324284e-12 1.10983458e-12 1.09643425e-12
#  1.08304275e-12 1.06966097e-12 1.05628985e-12 1.04293030e-12
#  1.02958328e-12 1.01624975e-12 1.00293069e-12 9.89627092e-13
#  9.76339974e-13 9.63070361e-13 9.49819299e-13 9.36587849e-13
#  9.23377091e-13 9.10188123e-13 8.97022059e-13 8.83880033e-13
#  8.70763196e-13 8.57672719e-13 8.44609791e-13 8.31575621e-13
#  8.18571436e-13 8.05598485e-13 7.92658037e-13 7.79751379e-13
#  7.66879822e-13 7.54044697e-13 7.41247355e-13 7.28489171e-13
#  7.15771540e-13 7.03095882e-13 6.90463638e-13 6.77876272e-13
#  6.65335273e-13 6.52842152e-13 6.40398446e-13 6.28005716e-13
#  6.15665547e-13 6.03379551e-13 5.91149365e-13 5.78976652e-13
#  5.66863103e-13 5.54810433e-13 5.42820387e-13 5.30894738e-13
#  5.19035286e-13 5.07243859e-13 4.95522317e-13 4.83872546e-13
#  4.72296466e-13 4.60796025e-13 4.49373201e-13 4.38030007e-13
#  4.26768485e-13 4.15590711e-13 4.04498793e-13 3.93494874e-13
#  3.82581129e-13 3.71759768e-13 3.61033039e-13 3.50403222e-13
#  3.39872634e-13 3.29443631e-13 3.19118603e-13 3.08899982e-13
#  2.98790233e-13 2.88791866e-13 2.78907427e-13 2.69139504e-13
#  2.59490725e-13 2.49963760e-13 2.40561322e-13 2.31286167e-13
#  2.22141093e-13 2.13128944e-13 2.04252608e-13 1.95515020e-13
#  1.86919161e-13 1.78468058e-13 1.70164788e-13 1.62012476e-13
#  1.54014295e-13 1.46173471e-13 1.38493278e-13 1.30977045e-13
#  1.23628152e-13 1.16450032e-13 1.09446174e-13 1.02620123e-13
#  9.59754766e-14 8.95158930e-14 8.32450869e-14 7.71668322e-14
#  7.12849626e-14 6.56033727e-14 6.01260191e-14 5.48569209e-14
#  4.98001613e-14 4.49598882e-14 4.03403155e-14 3.59457240e-14
#  3.17804626e-14 2.78489494e-14 2.41556726e-14 2.07051921e-14
#  1.75021402e-14 1.45512229e-14 1.18572213e-14 9.42499265e-15
#  7.25947157e-15 5.36567140e-15 3.74868547e-15 2.41368836e-15
#  1.36593728e-15 6.10773390e-16 1.53623210e-16 1.88814639e-41]
# <ipython-input-8-490adfd2f98d>:100: RuntimeWarning: divide by zero encountered in divide
#   G_2 = m_l_b*(f_0*(m_1/q_2) + f_plus *(m_2/s_2)*(1-(m_1*m_2/q_2)) + f_90*2*(m_l_c/s_2))
# <ipython-input-8-490adfd2f98d>:100: RuntimeWarning: invalid value encountered in add
#   G_2 = m_l_b*(f_0*(m_1/q_2) + f_plus *(m_2/s_2)*(1-(m_1*m_2/q_2)) + f_90*2*(m_l_c/s_2))
# <ipython-input-8-490adfd2f98d>:101: RuntimeWarning: divide by zero encountered in divide
#   G_3 = m_l_c*(-f_0*(m_1/q_2) + f_plus*(m_2/s_2)*(1+(m_1*m_2/q_2))-f_90*2*(m_l_b/s_2))
# <ipython-input-8-490adfd2f98d>:101: RuntimeWarning: invalid value encountered in subtract
#   G_3 = m_l_c*(-f_0*(m_1/q_2) + f_plus*(m_2/s_2)*(1+(m_1*m_2/q_2))-f_90*2*(m_l_b/s_2))
# <ipython-input-8-490adfd2f98d>:105: RuntimeWarning: divide by zero encountered in divide
#   T_1 = 2*(m_l_b**2)*((h_plus/s_2) -((m_2)**2/(q_2*s_2))*h_90 - (1/s_1)*h_tilda_plus + ((m_1**2/(q_2*s_1)))*h_tilda_90)
# <ipython-input-8-490adfd2f98d>:105: RuntimeWarning: invalid value encountered in subtract
#   T_1 = 2*(m_l_b**2)*((h_plus/s_2) -((m_2)**2/(q_2*s_2))*h_90 - (1/s_1)*h_tilda_plus + ((m_1**2/(q_2*s_1)))*h_tilda_90)
# <ipython-input-8-490adfd2f98d>:106: RuntimeWarning: divide by zero encountered in divide
#   T2_0 = (m_l_c/s_2)*h_plus
# <ipython-input-8-490adfd2f98d>:107: RuntimeWarning: divide by zero encountered in divide
#   T2_1 = (1/2)*((m_l_b - m_l_c)/q_2)*((m_l_b**2 - m_l_c**2-q_2)/s_2)*h_90
# <ipython-input-8-490adfd2f98d>:109: RuntimeWarning: invalid value encountered in subtract
#   T_2 = 2*m_l_b*(T2_0 - T2_1 + T2_2)
# <ipython-input-8-490adfd2f98d>:110: RuntimeWarning: divide by zero encountered in divide
#   T_3 = 2*m_l_b*(-(m_l_b/s_2)*h_plus + (m_2/(2*q_2*s_2))*(m_l_b**2-m_l_c**2+q_2)*h_90 - (m_1/(2*q_2))*h_tilda_90)
# <ipython-input-8-490adfd2f98d>:110: RuntimeWarning: invalid value encountered in add
#   T_3 = 2*m_l_b*(-(m_l_b/s_2)*h_plus + (m_2/(2*q_2*s_2))*(m_l_b**2-m_l_c**2+q_2)*h_90 - (m_1/(2*q_2))*h_tilda_90)

# %%
#plotting
print((m_l_b**2 + m_l_c**2-m_tau**2)/(2*m_l_b*m_l_c))
w = np.linspace(1,1.2063032748874114,1000)
#w = np.linspace(1,((m_l_b**2+m_l_c**2-m_tau**2)/(2*m_l_b*m_l_c)),1000)
#w = np.linspace(1,((m_l_b**2+m_l_c**2-m_tau**2)/(2*m_l_b*m_l_c)),1000)
y_value= D_gamma(w)
# Create the plot
sns.set()
plt.plot(w, y_value)
plt.xlabel('w')
plt.ylabel('n_0')
plt.xlim(1.005,1.10)
#plt.ylim(0,0.4)
#plt.legend()
#plt.grid(True)

# Show the plot
plt.show()
# Out:
# 1.2063032748874114
# <ipython-input-8-490adfd2f98d>:100: RuntimeWarning: divide by zero encountered in divide
#   G_2 = m_l_b*(f_0*(m_1/q_2) + f_plus *(m_2/s_2)*(1-(m_1*m_2/q_2)) + f_90*2*(m_l_c/s_2))
# <ipython-input-8-490adfd2f98d>:100: RuntimeWarning: invalid value encountered in add
#   G_2 = m_l_b*(f_0*(m_1/q_2) + f_plus *(m_2/s_2)*(1-(m_1*m_2/q_2)) + f_90*2*(m_l_c/s_2))
# <ipython-input-8-490adfd2f98d>:101: RuntimeWarning: divide by zero encountered in divide
#   G_3 = m_l_c*(-f_0*(m_1/q_2) + f_plus*(m_2/s_2)*(1+(m_1*m_2/q_2))-f_90*2*(m_l_b/s_2))
# <ipython-input-8-490adfd2f98d>:101: RuntimeWarning: invalid value encountered in subtract
#   G_3 = m_l_c*(-f_0*(m_1/q_2) + f_plus*(m_2/s_2)*(1+(m_1*m_2/q_2))-f_90*2*(m_l_b/s_2))
# <ipython-input-8-490adfd2f98d>:105: RuntimeWarning: divide by zero encountered in divide
#   T_1 = 2*(m_l_b**2)*((h_plus/s_2) -((m_2)**2/(q_2*s_2))*h_90 - (1/s_1)*h_tilda_plus + ((m_1**2/(q_2*s_1)))*h_tilda_90)
# <ipython-input-8-490adfd2f98d>:105: RuntimeWarning: invalid value encountered in subtract
#   T_1 = 2*(m_l_b**2)*((h_plus/s_2) -((m_2)**2/(q_2*s_2))*h_90 - (1/s_1)*h_tilda_plus + ((m_1**2/(q_2*s_1)))*h_tilda_90)
# <ipython-input-8-490adfd2f98d>:106: RuntimeWarning: divide by zero encountered in divide
#   T2_0 = (m_l_c/s_2)*h_plus
# <ipython-input-8-490adfd2f98d>:107: RuntimeWarning: divide by zero encountered in divide
#   T2_1 = (1/2)*((m_l_b - m_l_c)/q_2)*((m_l_b**2 - m_l_c**2-q_2)/s_2)*h_90
# <ipython-input-8-490adfd2f98d>:109: RuntimeWarning: invalid value encountered in subtract
#   T_2 = 2*m_l_b*(T2_0 - T2_1 + T2_2)
# <ipython-input-8-490adfd2f98d>:110: RuntimeWarning: divide by zero encountered in divide
#   T_3 = 2*m_l_b*(-(m_l_b/s_2)*h_plus + (m_2/(2*q_2*s_2))*(m_l_b**2-m_l_c**2+q_2)*h_90 - (m_1/(2*q_2))*h_tilda_90)
# <ipython-input-8-490adfd2f98d>:110: RuntimeWarning: invalid value encountered in add
#   T_3 = 2*m_l_b*(-(m_l_b/s_2)*h_plus + (m_2/(2*q_2*s_2))*(m_l_b**2-m_l_c**2+q_2)*h_90 - (m_1/(2*q_2))*h_tilda_90)
