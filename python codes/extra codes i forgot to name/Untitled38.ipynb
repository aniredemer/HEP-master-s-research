# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cmath

G_F = 1.1663787*10**(-5)
V_cb = 40.9*10**(-3)
tau_l_b = 1.409*10**(-12)

tau_total = 6.58*10**(-25)/tau_l_b
#print(tau_total)

#masses(GeV)
m_l_b = 5.6202
m_l_c = 2.59225
m_tau = 1.77686
m_e = 0.000511
m_uon = 0.1057
m_b = 4.18
m_c = 1.275
#w =1.1
#spacing
#w = np.linspace(1,((m_l_b**2+m_l_c**2-m_tau**2)/(2*m_l_b*m_l_c)),1000)
#w =1.1
def D_gamma(w):
  w = np.linspace(1,1.2063032748874114,1000)
  #w = np.linspace(1,((m_l_b**2+m_l_c**2-m_tau**2)/(2*m_l_b*m_l_c)),1000)
  m_l = m_tau


  #wilson coefficents
  # C_V_LL = 0
  # C_V_RL = 0
  # C_S_LL = 0
  # C_S_RL = 0

  # C_A = (1+C_V_LL - C_V_RL)  #C_A = C_A_L (""''"""""""""""""""""""""""""""""""")
  # C_V = (1+C_V_LL + C_V_RL)  #C_V = C_V_L  (only left handed leptons considered)
  # C_P = C_S_LL - C_S_RL
  # C_S = C_S_LL + C_S_RL
  # C_T =0

  #L fit 6
  # C_S = -0.16
  # C_V = 1.26
  # C_A = 1.10
  # C_T = 0.01
  # C_P = -0.26

  # SM fit
  C_V = 1
  C_A = 1
  C_S = 0
  C_P = 0
  C_T = 0

  # #L fit 7
  # C_V = 1.70
  # C_A = 1.02
  # C_S = -1.32
  # C_P = -0.22
  # C_T = -0.01

  l = (m_l_b/m_l_c)
  m_1 = m_l_b + m_l_c
  m_2 = m_l_b - m_l_c


  #M's,q's,s
  m_w = m_l_b-w*m_l_c
  q_2 =(m_l_b**2+m_l_c**2 - 2*m_l_b*m_l_c*w)
  #s_2 = (m_l_b-m_l_c)**2-q_2
  #s_1 = (m_l_b+m_l_c)**2-q_2
  s_1 = 2*m_l_b*m_l_c*(w+1)
  s_2 = 2*m_l_b*m_l_c*(w-1)


  #defining f'sg'sh's
  #form factors
  f_0 = 0.545 + (-2.21)*(w-1)
  f_plus = 0.1628 + 1.16*(w-1)
  f_90 = 0.1690 + 0.57*(w-1)

  g_0 = 0.221 +  0.94*(w-1)
  g_plus = 0.582 + (-2.24)*(w-1)
  g_90 = 1.22 + (-6.1)*(w-1)

  h_plus = 0.1908 +0.47*(w-1)
  h_90 = 0.1860 + 0.98*(w-1)
  h_tilda_plus = 1.15 - 5.8*(w-1)
  h_tilda_90 = 0.543 -2.12*(w-1)





  #defining F,T,G's
  G_1 = -f_90
  G_2 = m_l_b*(f_0*(m_1/q_2) + f_plus *(m_2/s_2)*(1-(m_1*m_2/q_2)) + f_90*2*(m_l_c/s_2))
  G_3 = m_l_c*(-f_0*(m_1/q_2) + f_plus*(m_2/s_2)*(1+(m_1*m_2/q_2))-f_90*2*(m_l_b/s_2))
  F_1 = -g_90
  F_2 = m_l_b*(-g_0*(m_2/q_2) - g_plus*(m_1/s_1)*(1-((m_1*m_2)/q_2)) + g_90*2*(m_l_c/s_1))
  F_3 = m_l_c*(g_0*(m_2/q_2) - g_plus*(m_1/s_1)*(1+((m_1*m_2)/q_2)) + g_90*2*(m_l_b/s_1))
  T_1 = 2*(m_l_b**2)*((h_plus/s_2) -((m_2)**2/(q_2*s_2))*h_90 - (1/s_1)*h_tilda_plus + ((m_1**2/(q_2*s_1)))*h_tilda_90)
  T2_0 = (m_l_c/s_2)*h_plus
  T2_1 = (1/2)*((m_l_b - m_l_c)/q_2)*((m_l_b**2 - m_l_c**2-q_2)/s_2)*h_90
  T2_2 = (1/2)*((m_l_b +m_l_c)/q_2)*h_tilda_90
  T_2 = 2*m_l_b*(T2_0 - T2_1 + T2_2)
  T_3 = 2*m_l_b*(-(m_l_b/s_2)*h_plus + (m_2/(2*q_2*s_2))*(m_l_b**2-m_l_c**2+q_2)*h_90 - (m_1/(2*q_2))*h_tilda_90)
  T_4 = h_plus


  F_S = -(1/(m_b+m_c))*(m_2*F_1 + m_w*F_2 + (m_l_b*w-m_l_c)*F_3)
  F_P = (1/(m_b-m_c))*(-(m_l_b + m_l_c)*G_1 + (m_l_b-m_l_c*w)*G_2 + (m_l_b*w -m_l_c)*G_3)
  #defining w's
  w_1 =(1/2)*((w-1)*(abs(C_A))**2*F_1**2 + (w+1)*(abs(C_V))**2*G_1**2)

  w_2_0 = ((abs(C_A))**(2)/2)*(2*F_1*F_2 +(w+1)*F_2**(2) + ((2*m_l_b)/m_l_c)*((F_1+F_2)*(F_1+F_3)+w*F_2*F_3) + (m_l_b**(2)/m_l_c**(2))*(2*F_1*F_3+(w+1)*F_3**(2)))
  w_2_1 = ((abs(C_V))**(2)/2)*(2*G_1*G_2 + (w-1)*G_2**2 + ((2*m_l_b)/m_l_c)*(w*G_2*G_3 + (G_1-G_2)*(G_1 + G_3)) + (m_l_b/m_l_c)**(2)*((w-1)*G_3**2-2*G_1*G_3))
  w_2 = w_2_0 + w_2_1

  w_3 = 2*(m_l_b/m_l_c)*((C_A*np.conjugate(C_V)).real)*F_1*G_1

  w_4 = (1/2)*(m_l_b/m_l_c)**(2)*((abs(C_A))**(2)*(2*F_1*F_3 +(w+1)*F_3**2)-(abs(C_V))**(2)*(2*G_1*G_3 +(1-w)*G_3**(2)))

  w_5_0 = (F_1+F_2)*(F_1+F_3) + w*F_2*F_3 + (m_l_b/m_l_c)*(2*F_1*F_3 + (w+1)*F_3**2)
  w_5_1 = (G_1-G_2)*(G_1+G_3)+w*G_2*G_3 - (m_l_b/m_l_c)*(2*G_1*G_3 + (1-w)*G_3**2)
  w_5 = (-1)*(m_l_b/m_l_c)*((abs(C_A))**2*w_5_0 + (abs(C_V))**2*w_5_1)

  w_SP =(1/2)*((w+1)*(abs(C_P))**2*F_S**2 + (w-1)*(abs(C_S))**2*F_P**2)

  #W's for other SF's

  w_I1_0 = C_A*(np.conjugate(C_P))*(F_S*F_1*(1+(m_l_b/m_l_c)) + (1+w)*F_S*(F_2 +(m_l_b/m_l_c)*F_3))
  w_I1_1 = C_V*(np.conjugate(C_S))*(F_P*G_1*(1-(m_l_b/m_l_c)) - (1-w)*F_P*(G_2 +(m_l_b/m_l_c)*G_3))
  w_I1 = w_I1_0 + w_I1_1

  w_I2 = (m_l_b/m_l_c)*(C_V*np.conjugate(C_S)*F_P*(G_1 +(1-w)*G_3)- C_A*np.conjugate(C_P)*F_S*(F_1+(1+w)*F_3))


  w_I3 = np.conjugate(C_T)*C_P*F_S*(T_1*(1+w)+T_3 - (m_l_b/m_l_c)*(T_2+T_4)) - np.conjugate(C_T)*C_S*(m_l_b/m_l_c)*F_P*T_4

  w_I4_0 = F_1*T_1*(1+(m_l_b/m_l_c)) + (m_l_b/m_l_c)*F_1*(T_3-T_2)
  w_I4_1 = (F_2 + F_3*(m_l_b/m_l_c))*((m_l_b/m_l_c)*(T_2+T_4) - T_1*(1+w)-T_3)
  w_I4_2 = (m_l_b/m_l_c)*(G_1*(T_2+T_3) + T_4*(G_2 + (m_l_b/m_l_c)*G_3))
  w_I4 = np.conjugate(C_T)*C_A*(w_I4_0 - w_I4_1) - np.conjugate(C_T)*C_V*w_I4_2

  w_I5_0 = (F_1*(T_1 +T_3) +F_3*(T_1*(1+w)+ T_3 - (m_l_b/m_l_c)*(T_2+T_4)))
  w_I5_1 = (G_1*T_3 + (m_l_b/m_l_c)*G_3*T_4)
  w_I5 = -np.conjugate(C_T)*C_A*l*w_I5_0 + np.conjugate(C_T)*C_V*l*w_I5_1

  w_I6_0 = ((1-w)*(T_2 + T_3) + (1-(m_l_b/m_l_c))*T_4)
  w_I6_1 = ((m_l_b/m_l_c)*(T_2 + T_4) + T_4 +w*(T_3-T_2) - (m_l_b/m_l_c)*T_3)
  w_I6 = -np.conjugate(C_T)*C_A*F_1*w_I6_0 -np.conjugate(C_T)*C_V*G_1*w_I6_1

  w_I7_0 =  (T_3*(1-w)-l*T_4)
  w_I7_1 = (l*(T_2+T_4)+w*T_3)
  w_I7 = np.conjugate(C_T)*C_A*F_1*w_I7_0 + np.conjugate(C_T)*C_V*G_1*w_I7_1

  w_T_2_0 = (1/l)**2*((1+w)*T_1**2 + 2*T_1*T_3)
  w_T_2_1 = 2*(1/l)*(w*(w+1)*T_1**2 + T_1*(T_2 +2*w*T_3 + T_4) + T_2*T_3)
  w_T_2_2 = (1+w)*T_1**2 - 2*w*(T_2**2 + T_3**2) + 2*T_1*(2*w*(T_2+T_4) + T_3) +2*(T_2+T_3)*(T_2 + T_3 + 2*T_4)
  w_T_2_3 = 2*l*(T_1*(T_2 + T_4) + T_2*(T_3+2*T_4) + 2*T_4*(T_3 +T_4))
  w_T_2 = ((abs(C_T))**2/2)*(w_T_2_0 - w_T_2_1 + w_T_2_2 - w_T_2_3)

  w_T_3 = ((abs(C_T))**(2)/2)*((1+w)*T_1**2 + 2*T_1*T_3 + 2*(1-w)*T_3**2 -2*l*(T_1*(T_2+T_4)+ T_3*(T_2 +2*T_4)))

  w_T_4_0 = (1/l)*(w*(1+w)*T_1**(2) + 2*w*T_1*T_3)
  w_T_4_1 = -T_1**(2)*(1+w)-2*w*(T_2+T_4)*T_1 -2*T_3*(T_1 + T_2 + (1-w)*T_3 +T_4)
  w_T_4_2 = 2*l*(T_4*(T_1+T_2+2*T_3) + T_2*(T_1 + T_3) + T_4**2)
  w_T_4 = ((abs(C_T))**(2)/2)*(w_T_4_0 + w_T_4_1 + w_T_4_2)

  #defining A,B,C
  A_0 = 2*w_1 -w_2 +(m_w/m_l_b)*w_3 +w_SP + 4*(m_w/m_l_b)*((w_I3).real)
  A_1 = 8*(w_T_2 -(q_2/m_l_b**2)*w_T_3-(2*m_w/m_l_b)*w_T_4)
  A_2 = (m_l/m_l_b)*((w_I2 +4*w_I4 +4*(m_w/m_l_b)*w_I5 + 12*w_I7).real)
  A_3 = (m_l/m_l_b)**2*(w_4 -16*w_T_3)

  A = ((q_2-m_l**2)/m_l_b**2)*(A_0 +A_1 +A_2 +A_3)

  B = -2*(q_2/m_l_b**2)*(w_3 +4*(w_I3).real) + 4*(m_w/m_l_b)*(w_2 -16*w_T_2) + 2*(m_l/m_l_b)*((w_I1 -4*(m_w/m_l_b)*w_I4 -4*(q_2/m_l_b**2)*w_I5 +12*w_I6).real) + 2*(m_l/m_l_b)**2*(w_5 -32*w_T_4)

  C = -4*(w_2 -16*w_T_2)


  #defining a0,a1,a2
  a_0 = (q_2/(q_2-m_l**(2)))*A + (1/2)*(m_w/m_l_b)*B + ((q_2-m_l**(2))*m_w**(2)*C)/(4*q_2*m_l_b**(2))
  a_2 = (w**2 -1)*(m_l_c/m_l_b)**(2)*((q_2 - m_l**2)/(4*q_2))*C

  n_0_value = 3 * a_0 + a_2
  #D_gamma = G_F**2*(abs(V_cb))**2*m_l_c**3*m_l_b**2*np.sqrt(w**2-1)*(1-(m_l**2/q_2))**2*n_0_value*(1/24*np.pi**3)
  return n_0_value

print(D_gamma(w))
# Out:
# [       nan 0.07213267 0.07271209 0.07328993 0.07386617 0.07444084
#  0.07501392 0.07558543 0.07615537 0.07672373 0.07729054 0.07785578
#  0.07841946 0.07898159 0.07954217 0.0801012  0.08065868 0.08121463
#  0.08176904 0.08232191 0.08287326 0.08342308 0.08397137 0.08451815
#  0.08506341 0.08560715 0.08614939 0.08669012 0.08722935 0.08776708
#  0.08830332 0.08883806 0.08937132 0.08990309 0.09043338 0.09096219
#  0.09148953 0.09201539 0.09253979 0.09306272 0.0935842  0.09410421
#  0.09462277 0.09513989 0.09565555 0.09616977 0.09668255 0.09719389
#  0.0977038  0.09821229 0.09871934 0.09922497 0.09972918 0.10023198
#  0.10073336 0.10123333 0.1017319  0.10222906 0.10272483 0.1032192
#  0.10371217 0.10420376 0.10469396 0.10518278 0.10567022 0.10615629
#  0.10664098 0.1071243  0.10760626 0.10808686 0.1085661  0.10904398
#  0.10952051 0.1099957  0.11046953 0.11094203 0.11141319 0.11188301
#  0.1123515  0.11281866 0.1132845  0.11374902 0.11421221 0.1146741
#  0.11513467 0.11559393 0.11605189 0.11650854 0.1169639  0.11741796
#  0.11787073 0.11832222 0.11877242 0.11922133 0.11966897 0.12011533
#  0.12056042 0.12100425 0.1214468  0.1218881  0.12232814 0.12276692
#  0.12320445 0.12364073 0.12407577 0.12450956 0.12494212 0.12537344
#  0.12580353 0.12623239 0.12666002 0.12708643 0.12751163 0.1279356
#  0.12835837 0.12877992 0.12920027 0.12961942 0.13003737 0.13045412
#  0.13086968 0.13128405 0.13169723 0.13210923 0.13252005 0.13292969
#  0.13333817 0.13374547 0.1341516  0.13455657 0.13496038 0.13536303
#  0.13576453 0.13616488 0.13656408 0.13696214 0.13735905 0.13775483
#  0.13814947 0.13854299 0.13893537 0.13932663 0.13971677 0.14010579
#  0.14049369 0.14088049 0.14126617 0.14165075 0.14203422 0.1424166
#  0.14279788 0.14317807 0.14355717 0.14393518 0.14431211 0.14468796
#  0.14506273 0.14543643 0.14580906 0.14618062 0.14655112 0.14692056
#  0.14728894 0.14765626 0.14802254 0.14838776 0.14875194 0.14911508
#  0.14947718 0.14983824 0.15019827 0.15055728 0.15091525 0.15127221
#  0.15162814 0.15198306 0.15233696 0.15268986 0.15304174 0.15339263
#  0.15374251 0.15409139 0.15443928 0.15478618 0.15513209 0.15547702
#  0.15582096 0.15616392 0.15650591 0.15684693 0.15718698 0.15752605
#  0.15786417 0.15820133 0.15853753 0.15887277 0.15920707 0.15954041
#  0.15987282 0.16020428 0.1605348  0.16086439 0.16119304 0.16152077
#  0.16184757 0.16217344 0.1624984  0.16282244 0.16314557 0.16346778
#  0.16378909 0.1641095  0.164429   0.16474761 0.16506532 0.16538213
#  0.16569806 0.1660131  0.16632726 0.16664054 0.16695295 0.16726448
#  0.16757514 0.16788493 0.16819386 0.16850192 0.16880913 0.16911548
#  0.16942098 0.16972564 0.17002944 0.1703324  0.17063452 0.17093581
#  0.17123626 0.17153588 0.17183467 0.17213264 0.17242979 0.17272612
#  0.17302163 0.17331633 0.17361022 0.1739033  0.17419558 0.17448706
#  0.17477774 0.17506762 0.17535672 0.17564503 0.17593255 0.17621929
#  0.17650525 0.17679043 0.17707484 0.17735848 0.17764135 0.17792346
#  0.17820481 0.1784854  0.17876523 0.17904431 0.17932264 0.17960023
#  0.17987707 0.18015317 0.18042854 0.18070317 0.18097706 0.18125023
#  0.18152268 0.1817944  0.18206541 0.18233569 0.18260527 0.18287413
#  0.18314229 0.18340974 0.18367649 0.18394254 0.18420789 0.18447256
#  0.18473653 0.18499982 0.18526242 0.18552434 0.18578559 0.18604616
#  0.18630606 0.18656529 0.18682385 0.18708175 0.18733899 0.18759558
#  0.18785151 0.18810678 0.18836142 0.1886154  0.18886874 0.18912145
#  0.18937352 0.18962495 0.18987575 0.19012593 0.19037548 0.19062441
#  0.19087273 0.19112042 0.19136751 0.19161398 0.19185985 0.19210511
#  0.19234977 0.19259383 0.1928373  0.19308018 0.19332246 0.19356417
#  0.19380528 0.19404582 0.19428578 0.19452516 0.19476398 0.19500222
#  0.1952399  0.19547701 0.19571357 0.19594956 0.19618501 0.1964199
#  0.19665424 0.19688804 0.1971213  0.19735401 0.19758619 0.19781784
#  0.19804895 0.19827954 0.1985096  0.19873914 0.19896816 0.19919667
#  0.19942466 0.19965214 0.19987911 0.20010557 0.20033154 0.20055701
#  0.20078198 0.20100645 0.20123044 0.20145394 0.20167695 0.20189949
#  0.20212154 0.20234312 0.20256423 0.20278486 0.20300503 0.20322473
#  0.20344398 0.20366276 0.20388109 0.20409897 0.20431639 0.20453337
#  0.20474991 0.204966   0.20518166 0.20539688 0.20561167 0.20582603
#  0.20603996 0.20625347 0.20646655 0.20667922 0.20689147 0.20710332
#  0.20731475 0.20752577 0.20773639 0.20794661 0.20815644 0.20836586
#  0.2085749  0.20878354 0.2089918  0.20919968 0.20940717 0.20961429
#  0.20982103 0.2100274  0.2102334  0.21043904 0.21064431 0.21084922
#  0.21105377 0.21125797 0.21146181 0.21166531 0.21186846 0.21207127
#  0.21227373 0.21247586 0.21267766 0.21287912 0.21308025 0.21328106
#  0.21348154 0.2136817  0.21388154 0.21408107 0.21428029 0.2144792
#  0.2146778  0.2148761  0.2150741  0.2152718  0.21546921 0.21566633
#  0.21586315 0.21605969 0.21625595 0.21645192 0.21664762 0.21684305
#  0.2170382  0.21723308 0.2174277  0.21762205 0.21781615 0.21800998
#  0.21820356 0.21839689 0.21858997 0.21878281 0.2189754  0.21916775
#  0.21935987 0.21955175 0.21974339 0.21993481 0.220126   0.22031697
#  0.22050772 0.22069826 0.22088857 0.22107868 0.22126858 0.22145827
#  0.22164776 0.22183705 0.22202614 0.22221504 0.22240374 0.22259226
#  0.22278059 0.22296874 0.2231567  0.22334449 0.22353211 0.22371956
#  0.22390683 0.22409394 0.22428089 0.22446768 0.22465431 0.22484079
#  0.22502711 0.22521329 0.22539932 0.22558521 0.22577096 0.22595658
#  0.22614205 0.2263274  0.22651262 0.22669772 0.22688269 0.22706754
#  0.22725227 0.2274369  0.22762141 0.22780581 0.22799011 0.2281743
#  0.2283584  0.2285424  0.22872631 0.22891012 0.22909385 0.22927749
#  0.22946106 0.22964454 0.22982795 0.23001128 0.23019454 0.23037774
#  0.23056087 0.23074394 0.23092695 0.2311099  0.23129281 0.23147566
#  0.23165846 0.23184123 0.23202395 0.23220663 0.23238928 0.23257189
#  0.23275448 0.23293703 0.23311957 0.23330208 0.23348458 0.23366706
#  0.23384953 0.23403199 0.23421445 0.2343969  0.23457935 0.23476181
#  0.23494427 0.23512674 0.23530922 0.23549171 0.23567423 0.23585676
#  0.23603932 0.2362219  0.23640451 0.23658716 0.23676984 0.23695256
#  0.23713532 0.23731812 0.23750098 0.23768388 0.23786683 0.23804985
#  0.23823292 0.23841605 0.23859925 0.23878251 0.23896585 0.23914926
#  0.23933275 0.23951632 0.23969997 0.23988371 0.24006754 0.24025146
#  0.24043547 0.24061958 0.2408038  0.24098811 0.24117254 0.24135707
#  0.24154172 0.24172649 0.24191137 0.24209638 0.24228151 0.24246677
#  0.24265216 0.24283769 0.24302335 0.24320916 0.2433951  0.2435812
#  0.24376744 0.24395384 0.2441404  0.24432711 0.24451398 0.24470102
#  0.24488823 0.24507561 0.24526317 0.2454509  0.24563881 0.24582691
#  0.24601519 0.24620366 0.24639233 0.24658119 0.24677026 0.24695952
#  0.24714899 0.24733867 0.24752856 0.24771866 0.24790899 0.24809953
#  0.2482903  0.2484813  0.24867252 0.24886399 0.24905568 0.24924762
#  0.2494398  0.24963223 0.24982491 0.25001784 0.25021103 0.25040448
#  0.25059819 0.25079216 0.2509864  0.25118092 0.25137571 0.25157078
#  0.25176613 0.25196177 0.25215769 0.25235391 0.25255042 0.25274723
#  0.25294434 0.25314176 0.25333948 0.25353752 0.25373586 0.25393453
#  0.25413352 0.25433283 0.25453247 0.25473244 0.25493274 0.25513338
#  0.25533437 0.25553569 0.25573737 0.25593939 0.25614177 0.25634451
#  0.2565476  0.25675106 0.25695489 0.25715909 0.25736367 0.25756862
#  0.25777395 0.25797967 0.25818577 0.25839227 0.25859916 0.25880645
#  0.25901414 0.25922224 0.25943074 0.25963966 0.25984899 0.26005874
#  0.26026891 0.26047951 0.26069054 0.260902   0.26111389 0.26132623
#  0.26153901 0.26175223 0.26196591 0.26218004 0.26239463 0.26260967
#  0.26282519 0.26304117 0.26325762 0.26347455 0.26369195 0.26390984
#  0.26412821 0.26434708 0.26456643 0.26478629 0.26500664 0.2652275
#  0.26544886 0.26567074 0.26589313 0.26611604 0.26633948 0.26656343
#  0.26678792 0.26701294 0.2672385  0.2674646  0.26769125 0.26791844
#  0.26814619 0.26837449 0.26860335 0.26883277 0.26906276 0.26929332
#  0.26952446 0.26975617 0.26998847 0.27022136 0.27045483 0.2706889
#  0.27092356 0.27115883 0.27139471 0.27163119 0.27186828 0.272106
#  0.27234433 0.27258329 0.27282288 0.2730631  0.27330396 0.27354546
#  0.27378761 0.2740304  0.27427385 0.27451795 0.27476272 0.27500815
#  0.27525425 0.27550102 0.27574847 0.27599661 0.27624542 0.27649493
#  0.27674513 0.27699603 0.27724763 0.27749994 0.27775296 0.27800669
#  0.27826114 0.27851632 0.27877222 0.27902885 0.27928622 0.27954433
#  0.27980318 0.28006278 0.28032314 0.28058425 0.28084613 0.28110877
#  0.28137218 0.28163636 0.28190132 0.28216707 0.28243361 0.28270093
#  0.28296906 0.28323798 0.28350772 0.28377826 0.28404961 0.28432179
#  0.28459479 0.28486862 0.28514328 0.28541878 0.28569512 0.2859723
#  0.28625034 0.28652923 0.28680899 0.28708961 0.2873711  0.28765346
#  0.28793671 0.28822084 0.28850586 0.28879177 0.28907858 0.28936629
#  0.28965491 0.28994445 0.2902349  0.29052627 0.29081858 0.29111181
#  0.29140598 0.2917011  0.29199716 0.29229418 0.29259215 0.29289109
#  0.29319099 0.29349187 0.29379372 0.29409656 0.29440038 0.2947052
#  0.29501101 0.29531783 0.29562566 0.2959345  0.29624436 0.29655525
#  0.29686717 0.29718012 0.29749411 0.29780914 0.29812523 0.29844238
#  0.29876058 0.29907986 0.2994002  0.29972163 0.30004414 0.30036774
#  0.30069243 0.30101822 0.30134512 0.30167314 0.30200227 0.30233252
#  0.3026639  0.30299642 0.30333008 0.30366488 0.30400083 0.30433795
#  0.30467622 0.30501567 0.30535629 0.30569809 0.30604108 0.30638526
#  0.30673065 0.30707724 0.30742503 0.30777405 0.30812429 0.30847576
#  0.30882847 0.30918242 0.30953761 0.30989406 0.31025178 0.31061076
#  0.31097101 0.31133254 0.31169536 0.31205947 0.31242488 0.3127916
#  0.31315963 0.31352898 0.31389965 0.31427166 0.314645   0.3150197
#  0.31539574 0.31577314 0.31615191 0.31653205 0.31691356 0.31729647
#  0.31768077 0.31806647 0.31845357 0.31884209 0.31923203 0.3196234
#  0.32001621 0.32041046 0.32080615 0.32120331 0.32160193 0.32200202
#  0.32240359 0.32280665 0.32321119 0.32361725 0.32402481 0.32443388
#  0.32484448 0.32525662 0.32567029 0.3260855  0.32650228 0.32692061
#  0.32734052 0.327762   0.32818507 0.32860974 0.329036   0.32946388
#  0.32989337 0.33032449 0.33075725 0.33119164 0.33162769 0.3320654
#  0.33250478 0.33294583 0.33338856 0.33383299 0.33427912 0.33472696
#  0.33517652 0.33562781 0.33608083 0.3365356  0.33699212 0.3374504
#  0.33791046 0.3383723  0.33883592 0.33930135 0.33976858 0.34023763
#  0.3407085  0.34118122 0.34165577 0.34213218 0.34261046 0.3430906
#  0.34357264 0.34405656 0.34454238 0.34503012 0.34551978 0.34601137
#  0.34650491 0.34700039 0.34749784 0.34799725 0.34849865 0.34900205
#  0.34950744 0.35001485 0.35052428 0.35103574 0.35154925 0.35206482
#  0.35258245 0.35310215 0.35362395 0.35414784 0.35467384 0.35520196
#  0.35573221 0.3562646  0.35679915 0.35733586 0.35787475 0.35841583
#  0.3589591  0.35950459 0.3600523  0.36060224 0.36115443 0.36170887
#  0.36226559 0.36282459 0.36338588 0.36394948 0.3645154  0.36508365
#  0.36565424 0.36622719 0.3668025  0.3673802  0.36796029 0.36854279
#  0.36912771 0.36971506 0.37030486 0.37089712 0.37149185 0.37208907
#  0.37268878 0.37329101 0.37389577 0.37450306 0.37511292 0.37572534
#  0.37634034 0.37695794 0.37757815 0.37820098 0.37882646 0.37945459
#  0.38008539 0.38071887 0.38135505 0.38199395 0.38263557 0.38327994
#  0.38392707 0.38457697 0.38522966 0.38588516 0.38654348 0.38720464
#  0.38786865 0.38853553 0.3892053  0.38987797]
# <ipython-input-7-de9db2cd7e26>:99: RuntimeWarning: divide by zero encountered in divide
#   G_2 = m_l_b*(f_0*(m_1/q_2) + f_plus *(m_2/s_2)*(1-(m_1*m_2/q_2)) + f_90*2*(m_l_c/s_2))
# <ipython-input-7-de9db2cd7e26>:99: RuntimeWarning: invalid value encountered in add
#   G_2 = m_l_b*(f_0*(m_1/q_2) + f_plus *(m_2/s_2)*(1-(m_1*m_2/q_2)) + f_90*2*(m_l_c/s_2))
# <ipython-input-7-de9db2cd7e26>:100: RuntimeWarning: divide by zero encountered in divide
#   G_3 = m_l_c*(-f_0*(m_1/q_2) + f_plus*(m_2/s_2)*(1+(m_1*m_2/q_2))-f_90*2*(m_l_b/s_2))
# <ipython-input-7-de9db2cd7e26>:100: RuntimeWarning: invalid value encountered in subtract
#   G_3 = m_l_c*(-f_0*(m_1/q_2) + f_plus*(m_2/s_2)*(1+(m_1*m_2/q_2))-f_90*2*(m_l_b/s_2))
# <ipython-input-7-de9db2cd7e26>:104: RuntimeWarning: divide by zero encountered in divide
#   T_1 = 2*(m_l_b**2)*((h_plus/s_2) -((m_2)**2/(q_2*s_2))*h_90 - (1/s_1)*h_tilda_plus + ((m_1**2/(q_2*s_1)))*h_tilda_90)
# <ipython-input-7-de9db2cd7e26>:104: RuntimeWarning: invalid value encountered in subtract
#   T_1 = 2*(m_l_b**2)*((h_plus/s_2) -((m_2)**2/(q_2*s_2))*h_90 - (1/s_1)*h_tilda_plus + ((m_1**2/(q_2*s_1)))*h_tilda_90)
# <ipython-input-7-de9db2cd7e26>:105: RuntimeWarning: divide by zero encountered in divide
#   T2_0 = (m_l_c/s_2)*h_plus
# <ipython-input-7-de9db2cd7e26>:106: RuntimeWarning: divide by zero encountered in divide
#   T2_1 = (1/2)*((m_l_b - m_l_c)/q_2)*((m_l_b**2 - m_l_c**2-q_2)/s_2)*h_90
# <ipython-input-7-de9db2cd7e26>:108: RuntimeWarning: invalid value encountered in subtract
#   T_2 = 2*m_l_b*(T2_0 - T2_1 + T2_2)
# <ipython-input-7-de9db2cd7e26>:109: RuntimeWarning: divide by zero encountered in divide
#   T_3 = 2*m_l_b*(-(m_l_b/s_2)*h_plus + (m_2/(2*q_2*s_2))*(m_l_b**2-m_l_c**2+q_2)*h_90 - (m_1/(2*q_2))*h_tilda_90)
# <ipython-input-7-de9db2cd7e26>:109: RuntimeWarning: invalid value encountered in add
#   T_3 = 2*m_l_b*(-(m_l_b/s_2)*h_plus + (m_2/(2*q_2*s_2))*(m_l_b**2-m_l_c**2+q_2)*h_90 - (m_1/(2*q_2))*h_tilda_90)

# %%
#plotting
print((m_l_b**2 + m_l_c**2-m_tau**2)/(2*m_l_b*m_l_c))
w = np.linspace(1,1.2063032748874114,1000)
#w = np.linspace(1,((m_l_b**2+m_l_c**2-m_tau**2)/(2*m_l_b*m_l_c)),1000)
y_value= D_gamma(w)
# Create the plot
sns.set()
plt.plot(w, y_value)
plt.xlabel('w')
plt.ylabel('n_0')
plt.xlim(1.005,1.10)
plt.ylim(0,0.4)
#plt.legend()
#plt.grid(True)

# Show the plot
plt.show()
# Out:
# 1.2063032748874114
# <ipython-input-7-de9db2cd7e26>:99: RuntimeWarning: divide by zero encountered in divide
#   G_2 = m_l_b*(f_0*(m_1/q_2) + f_plus *(m_2/s_2)*(1-(m_1*m_2/q_2)) + f_90*2*(m_l_c/s_2))
# <ipython-input-7-de9db2cd7e26>:99: RuntimeWarning: invalid value encountered in add
#   G_2 = m_l_b*(f_0*(m_1/q_2) + f_plus *(m_2/s_2)*(1-(m_1*m_2/q_2)) + f_90*2*(m_l_c/s_2))
# <ipython-input-7-de9db2cd7e26>:100: RuntimeWarning: divide by zero encountered in divide
#   G_3 = m_l_c*(-f_0*(m_1/q_2) + f_plus*(m_2/s_2)*(1+(m_1*m_2/q_2))-f_90*2*(m_l_b/s_2))
# <ipython-input-7-de9db2cd7e26>:100: RuntimeWarning: invalid value encountered in subtract
#   G_3 = m_l_c*(-f_0*(m_1/q_2) + f_plus*(m_2/s_2)*(1+(m_1*m_2/q_2))-f_90*2*(m_l_b/s_2))
# <ipython-input-7-de9db2cd7e26>:104: RuntimeWarning: divide by zero encountered in divide
#   T_1 = 2*(m_l_b**2)*((h_plus/s_2) -((m_2)**2/(q_2*s_2))*h_90 - (1/s_1)*h_tilda_plus + ((m_1**2/(q_2*s_1)))*h_tilda_90)
# <ipython-input-7-de9db2cd7e26>:104: RuntimeWarning: invalid value encountered in subtract
#   T_1 = 2*(m_l_b**2)*((h_plus/s_2) -((m_2)**2/(q_2*s_2))*h_90 - (1/s_1)*h_tilda_plus + ((m_1**2/(q_2*s_1)))*h_tilda_90)
# <ipython-input-7-de9db2cd7e26>:105: RuntimeWarning: divide by zero encountered in divide
#   T2_0 = (m_l_c/s_2)*h_plus
# <ipython-input-7-de9db2cd7e26>:106: RuntimeWarning: divide by zero encountered in divide
#   T2_1 = (1/2)*((m_l_b - m_l_c)/q_2)*((m_l_b**2 - m_l_c**2-q_2)/s_2)*h_90
# <ipython-input-7-de9db2cd7e26>:108: RuntimeWarning: invalid value encountered in subtract
#   T_2 = 2*m_l_b*(T2_0 - T2_1 + T2_2)
# <ipython-input-7-de9db2cd7e26>:109: RuntimeWarning: divide by zero encountered in divide
#   T_3 = 2*m_l_b*(-(m_l_b/s_2)*h_plus + (m_2/(2*q_2*s_2))*(m_l_b**2-m_l_c**2+q_2)*h_90 - (m_1/(2*q_2))*h_tilda_90)
# <ipython-input-7-de9db2cd7e26>:109: RuntimeWarning: invalid value encountered in add
#   T_3 = 2*m_l_b*(-(m_l_b/s_2)*h_plus + (m_2/(2*q_2*s_2))*(m_l_b**2-m_l_c**2+q_2)*h_90 - (m_1/(2*q_2))*h_tilda_90)
